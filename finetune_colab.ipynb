# %%
! pip install gliner
! pip install accelerate -U
# Out:
# Requirement already satisfied: gliner in /usr/local/lib/python3.10/dist-packages (0.2.13)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gliner) (2.5.0+cu121)
# Requirement already satisfied: transformers>=4.38.2 in /usr/local/lib/python3.10/dist-packages (from gliner) (4.44.2)
# Requirement already satisfied: huggingface-hub>=0.21.4 in /usr/local/lib/python3.10/dist-packages (from gliner) (0.24.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gliner) (4.66.5)
# Requirement already satisfied: onnxruntime in /usr/local/lib/python3.10/dist-packages (from gliner) (1.19.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from gliner) (0.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.4->gliner) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gliner) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gliner) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->gliner) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.0.0->gliner) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->gliner) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->gliner) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->gliner) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.38.2->gliner) (0.19.1)
# Requirement already satisfied: coloredlogs in /usr/local/lib/python3.10/dist-packages (from onnxruntime->gliner) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime->gliner) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime->gliner) (3.20.3)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.10/dist-packages (from coloredlogs->onnxruntime->gliner) (10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->gliner) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.4->gliner) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.4->gliner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.4->gliner) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.4->gliner) (2024.8.30)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.2)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.5.0+cu121)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.24.7)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2024.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.0->accelerate) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.8.30)

# %%
import json
import random

# %%
with open("train.json") as f:
  train_dataset = json.load(f)

with open("eval.json") as f:
  test_dataset = json.load(f)

# %%
train_dataset
# Out:
# [{'tokenized_text': ['Seismic',
#    'interpreter',
#    'ci',
#    'ha',
#    'notificato',
#    'degli',
#    'aggiornamenti',
#    'sul',
#    'sito',
#    'di',
#    'estrazione',
#    '.',
#    'Puoi',
#    'visitare',
#    'http://www.basadonna-tolentino.net/',
#    'per',
#    'maggiori',
#    'dettagli',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['Caro',
#    'Cantagalli',
#    ',',
#    'non',
#    'dimenticare',
#    'il',
#    'tuo',
#    'appuntamento',
#    'con',
#    'Signorina',
#    'alle',
#    '093879960',
#    '.',
#    'Ti',
#    'invio',
#    'i',
#    'dettagli',
#    'via',
#    'C@yahoo.com',
#    '.'],
#   'ner': [[1, 1, 'SURNAME'], [18, 18, 'EMAIL']]},
#  {'tokenized_text': ['Profili',
#    'medici',
#    'aggiornati',
#    'su',
#    'Sibar',
#    'con',
#    'sistema',
#    'Bürglen',
#    '(',
#    'Uri',
#    ')',
#    'Messi',
#    'in',
#    'IPV6',
#    '[',
#    'IPV6_13',
#    ']',
#    '.',
#    'Nuove',
#    'misurazioni',
#    '.',
#    'Altezza',
#    '175',
#    'cm',
#    'cm.'],
#   'ner': [[4, 4, 'GIVENNAME'], [7, 10, 'CITY']]},
#  {'tokenized_text': ["L'",
#    'organisateur',
#    'de',
#    'notre',
#    'prochaine',
#    'discussion',
#    'a',
#    'une',
#    'adresse',
#    'Bitcoin',
#    'pour',
#    'les',
#    'dons',
#    ':',
#    '3azGz0nrkiRf8yS0O5PSCToKjIbiOlgDRN',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['1983hilarius.halliger',
#    "'s",
#    'recent',
#    'scores',
#    'in',
#    'behavior',
#    '.',
#    'Data',
#    'at',
#    'https://www.mccarthy.net/',
#    ',',
#    'please',
#    'review',
#    '.'],
#   'ner': [[0, 0, 'USERNAME']]},
#  {'tokenized_text': ['Buongiorno',
#    ',',
#    'la',
#    'donazione',
#    'di',
#    '929964.46',
#    'EUR',
#    'è',
#    'stata',
#    'registrata',
#    'correttamente',
#    '.',
#    'Per',
#    'favore',
#    ',',
#    'verifica',
#    'l’',
#    'indirizzo',
#    'RV',
#    '704',
#    '.',
#    'Cordiali',
#    'saluti',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Hello',
#    'Sound',
#    'technician',
#    ',',
#    'broadcasting',
#    '/',
#    'film',
#    '/',
#    'video',
#    ',',
#    'there',
#    "'s",
#    'an',
#    'article',
#    'at',
#    'http://clark.biz/',
#    'on',
#    'elderly',
#    'mental',
#    'health',
#    '.',
#    'Confirm',
#    'vivquenne',
#    "'s",
#    '6264756',
#    'is',
#    'correctly',
#    'listed',
#    'in',
#    'the',
#    'system',
#    '.'],
#   'ner': [[22, 22, 'USERNAME']]},
#  {'tokenized_text': ['<',
#    'html><body><p',
#    '>',
#    "L'",
#    'accordo',
#    'di',
#    'fornitura',
#    'per',
#    "l'",
#    'account',
#    '522134',
#    'richiede',
#    'conferma',
#    '.',
#    'Accedi',
#    'a',
#    'http://www.atkins-carlson.info/',
#    'per',
#    'ulteriori',
#    'dettagli',
#    '.',
#    'Saldo',
#    'attuale',
#    ':',
#    '537739.</p></body></html',
#    '>'],
#   'ner': [[10, 10, 'ACCOUNTNUM']]},
#  {'tokenized_text': ['Sindaca',
#    'Valguarnera',
#    ',',
#    'mi',
#    'puoi',
#    'dare',
#    'il',
#    'tuo',
#    'numero',
#    'social',
#    '756',
#    '0941',
#    '6118',
#    '02',
#    'per',
#    'il',
#    'modulo',
#    'di',
#    'iscrizione',
#    'alla',
#    'terapia',
#    'musicale',
#    '?'],
#   'ner': [[1, 1, 'SURNAME'], [10, 13, 'SOCIALNUM']]},
#  {'tokenized_text': ['<',
#    'div',
#    '>',
#    'Agreement',
#    'for',
#    'payment',
#    'guarantee</div><div',
#    '>',
#    'Contractor',
#    ':',
#    'Chungdak',
#    'Baccar</div><div',
#    '>',
#    'Subcontractor',
#    ':',
#    'Chungdak',
#    'Baccar</div><div',
#    '>',
#    'Payment',
#    ':',
#    'British',
#    'Pound',
#    'Sterling</div><div',
#    '>',
#    'Document',
#    ':',
#    'NUM-201906',
#    '-',
#    '4843</div><div',
#    '>',
#    'Bitcoin',
#    'Address',
#    ':',
#    '3NoZhFxuefukM3VvZ7AWA2lCpCiN5B6jVE</div><div',
#    '>',
#    'Ethereum',
#    'Address',
#    ':',
#    '0x4f9faab372e53ce5591abe5902491b66185b4432</div><div',
#    '>',
#    'Contact',
#    'at',
#    'chungdak.baccar@protonmail.com</div',
#    '>'],
#   'ner': [[10, 10, 'GIVENNAME'], [15, 15, 'GIVENNAME']]},
#  {'tokenized_text': ['Bonjour',
#    'Fissehaye',
#    ',',
#    'en',
#    'tant',
#    'que',
#    'responsable',
#    "d'",
#    'élevage',
#    'agricole',
#    ',',
#    'pourriez',
#    '-vous',
#    'valider',
#    'les',
#    'informations',
#    'envoyées',
#    'à',
#    '90munzur@hotmail.com',
#    '?',
#    'Important',
#    'pour',
#    'notre',
#    'analyse',
#    'juridique',
#    '.'],
#   'ner': [[1, 1, 'GIVENNAME'], [18, 18, 'EMAIL']]},
#  {'tokenized_text': ['Need',
#    'detail',
#    'on',
#    'water',
#    'conservation',
#    'laws',
#    'in',
#    '80642',
#    '.',
#    'Vehicle',
#    'UZSAMTBC0ZT5LRYL7',
#    'was',
#    'reported',
#    'by',
#    'Corunha',
#    ',',
#    'might',
#    'not',
#    'comply',
#    'with',
#    'them',
#    '.'],
#   'ner': [[7, 7, 'ZIPCODE'], [14, 14, 'SURNAME']]},
#  {'tokenized_text': ['Le',
#    'médicament',
#    'défectueux',
#    'vendu',
#    'par',
#    "l'",
#    'accusé',
#    'a',
#    'causé',
#    'des',
#    'dommages',
#    'irréversibles',
#    '.',
#    'Plainte',
#    'inclut',
#    'les',
#    'numéros',
#    'de',
#    'passeport',
#    'R8319644',
#    'et',
#    'R8319644',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['¡',
#    '<',
#    'DOCTYPE',
#    'html',
#    '>',
#    '\n',
#    '<',
#    'html',
#    '>',
#    '\n',
#    '<',
#    'body',
#    '>',
#    '\n',
#    '<',
#    'p',
#    '>',
#    'Para',
#    'garantizar',
#    'la',
#    'privacidad',
#    'de',
#    'los',
#    'datos',
#    'de',
#    'seguro',
#    ',',
#    'este',
#    'acuerdo',
#    'incluye',
#    'auditoría',
#    'continua',
#    'de',
#    'accesos',
#    'desde',
#    'direcciones',
#    'como',
#    '[',
#    'IPV6_12',
#    ']',
#    '.',
#    'Usuarios',
#    'como',
#    'vasvihagen',
#    'tienen',
#    'su',
#    'VIN',
#    'CVY6BMBJ2X4N9J02E',
#    'asegurado.</p',
#    '>',
#    '\n',
#    '<',
#    '/body',
#    '>',
#    '\n',
#    '<',
#    '/html',
#    '>'],
#   'ner': [[43, 43, 'USERNAME']]},
#  {'tokenized_text': ['Ciao',
#    ',',
#    'il',
#    'C.F.',
#    'Jou',
#    'Bou',
#    '26',
#    'N',
#    '82',
#    '2',
#    'BUM',
#    'è',
#    'necessario',
#    'per',
#    'confermare',
#    "l'",
#    'account',
#    '.'],
#   'ner': [[4, 10, 'SOCIALNUM']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Confidentialité:</p><p',
#    '>',
#    'Le',
#    'patient',
#    'montre',
#    'des',
#    'troubles',
#    'à',
#    'Villa',
#    '398',
#    '.',
#    'Adresse',
#    'IP',
#    ':',
#    '[',
#    'IPV4_1].',
#    'Utiliser',
#    'le',
#    'code',
#    'OTP',
#    ':',
#    '820',
#    '84',
#    ':',
#    'et',
#    'MRMLZ2BL46F5RRK0F',
#    'pour',
#    'la',
#    'vérification.</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['Hey',
#    'Boukhalfa',
#    ',',
#    'per',
#    'favore',
#    ',',
#    'aggiorna',
#    'i',
#    'tuoi',
#    'dettagli',
#    'di',
#    'IT49091211859',
#    'per',
#    'iscriversi',
#    'alla',
#    'nuova',
#    'campagna',
#    'di',
#    'promozione',
#    'salute',
#    'a',
#    'partire',
#    'dalla',
#    'prossima',
#    'settimana',
#    '.'],
#   'ner': [[1, 1, 'SURNAME'], [11, 11, 'TAXNUM']]},
#  {'tokenized_text': ['2',
#    '.',
#    'Employee',
#    'Roles',
#    'and',
#    'Responsibilities',
#    'Certificate',
#    'of',
#    'Deposit',
#    'Account',
#    ',',
#    'titled',
#    'Pres',
#    ',',
#    'holds',
#    'the',
#    'IDCARDNUM',
#    'QK08136WQ',
#    'and',
#    'earns',
#    '78139.81',
#    '.',
#    'Detailed',
#    'position',
#    'updates',
#    'at',
#    'https://waters.info/.',
#    'Send',
#    'inquiries',
#    'to',
#    'rémondrec@gmail.com',
#    '.'],
#   'ner': [[17, 17, 'IDCARDNUM'], [30, 30, 'EMAIL']]},
#  {'tokenized_text': ['Scoring',
#    'rubrics',
#    'will',
#    'be',
#    'shared',
#    'via',
#    '11dale.lutfi@yahoo.com',
#    '.',
#    'Ensure',
#    'to',
#    'include',
#    'your',
#    'UU84209RD',
#    'on',
#    'all',
#    'submissions',
#    'for',
#    'tracking',
#    '.',
#    'Evaluation',
#    'criteria',
#    'to',
#    'be',
#    'outlined',
#    'during',
#    'the',
#    'session',
#    'on',
#    '02/09/2058',
#    '.'],
#   'ner': [[6, 6, 'EMAIL'], [12, 12, 'IDCARDNUM']]},
#  {'tokenized_text': ['Querido',
#    'Príncipe',
#    ',',
#    'he',
#    'leído',
#    'sobre',
#    'tu',
#    'estudio',
#    'del',
#    'sueño',
#    'en',
#    'trabajadores',
#    'de',
#    'Medio',
#    'tiempo',
#    'en',
#    'AN',
#    '.',
#    'Necesito',
#    'más',
#    'datos',
#    'para',
#    'un',
#    'proyecto',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Salut',
#    ',',
#    'pour',
#    'accéder',
#    'à',
#    'votre',
#    'compte',
#    ',',
#    'utilisez',
#    'le',
#    'code',
#    'PIN',
#    '09436',
#    'envoyé',
#    'par',
#    'email',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Hi',
#    'there',
#    ',',
#    'make',
#    'sure',
#    'to',
#    'document',
#    'the',
#    'driver',
#    '’s',
#    'license',
#    'number',
#    'S041699705161',
#    'for',
#    'compliance',
#    'purposes',
#    '.'],
#   'ner': [[12, 12, 'DRIVERLICENSENUM']]},
#  {'tokenized_text': ['Welk',
#    'adres',
#    'zijn',
#    'ze',
#    'aan',
#    'het',
#    'gebruiken',
#    'voor',
#    'de',
#    'facturering',
#    '?',
#    'Ze',
#    'zouden',
#    'mijn',
#    'NLXM4J',
#    '8316485408',
#    'moeten',
#    'updaten',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'La',
#    'proprietà',
#    'a',
#    'Bellinzona',
#    'è',
#    'stata',
#    'stimata',
#    '538.5k',
#    'CHF',
#    '.',
#    'Proprietario',
#    ':',
#    'Jarmo',
#    ',',
#    'numero',
#    'di',
#    'licenza',
#    ':',
#    '8997158846',
#    '.',
#    'Indirizzo',
#    'Litecoin',
#    ':',
#    'LbOuSWomY58iiosRgXqZcsop9pD9eokygG.</p',
#    '>'],
#   'ner': [[6, 6, 'CITY'],
#    [15, 15, 'GIVENNAME'],
#    [21, 21, 'DRIVERLICENSENUM']]},
#  {'tokenized_text': ['Ciao',
#    ',',
#    'i',
#    'risultati',
#    'sono',
#    'pronti',
#    '.',
#    'Puoi',
#    'accedere',
#    'con',
#    'USERNAME',
#    ':',
#    '95heaven',
#    'e',
#    'PASSWORD',
#    ':',
#    ')',
#    'oC1R.'],
#   'ner': [[12, 12, 'USERNAME']]},
#  {'tokenized_text': ['Hello',
#    'Rosloveanu',
#    ',',
#    'can',
#    'you',
#    'make',
#    'sure',
#    'we',
#    'have',
#    'the',
#    'correct',
#    'URL',
#    'https://www.berry.com/',
#    'and',
#    'the',
#    'ZIP',
#    'code',
#    'is',
#    'still',
#    'CM21',
#    '?'],
#   'ner': [[1, 1, 'SURNAME'], [19, 19, 'ZIPCODE']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Développer',
#    'les',
#    'compétences',
#    'en',
#    'technologie',
#    'éducative',
#    '.',
#    'Date',
#    ':',
#    '2026',
#    '-',
#    '12',
#    '-',
#    '31T00:00:00',
#    '.',
#    'Adresse',
#    'Bitcoin',
#    ':',
#    '3fpLQClzMWGdvZfXjFsyaMD8tdXBsI6C7k',
#    '.',
#    'Numéro',
#    'de',
#    'passeport',
#    'requis',
#    ':',
#    'G6146034',
#    '.',
#    'Numéro',
#    'de',
#    'sécurité',
#    'sociale',
#    ':',
#    '756.4014.0090.23',
#    '.',
#    'Responsable',
#    ':',
#    'Vermeil',
#    '.',
#    'IBAN',
#    'pour',
#    'frais',
#    ':',
#    'CH45965096019524035.</p',
#    '>'],
#   'ner': [[35, 35, 'SOCIALNUM']]},
#  {'tokenized_text': ['Buongiorno',
#    'Valerio',
#    ',',
#    'possiamo',
#    'discutere',
#    'il',
#    'nuovo',
#    'esercizio',
#    'di',
#    'auto',
#    '-',
#    'compassione',
#    'oggi',
#    'pomeriggio',
#    '?'],
#   'ner': [[1, 1, 'GIVENNAME']]},
#  {'tokenized_text': ['*',
#    '*',
#    'Health',
#    'Advocacy',
#    'Form**|Form',
#    'to',
#    'officially',
#    'register',
#    'for',
#    'health',
#    'advocacy',
#    'programs',
#    'and',
#    'activities.||HTML||Fill',
#    'out',
#    'your',
#    'information',
#    ':',
#    'Siloam',
#    'Road',
#    ',',
#    'Pueblo',
#    ',',
#    '11th',
#    'June',
#    '2012',
#    ',',
#    'Brown',
#    '.',
#    'Crucial',
#    'for',
#    'your',
#    'involvement',
#    'in',
#    'health',
#    'programs',
#    '.'],
#   'ner': [[18, 19, 'STREET'], [21, 21, 'CITY']]},
#  {'tokenized_text': ['For',
#    'improved',
#    'educational',
#    'outcomes',
#    ',',
#    'parents',
#    'and',
#    'teachers',
#    'will',
#    'collaborate',
#    'continuously',
#    '.',
#    'Regular',
#    'updates',
#    'sent',
#    'via',
#    'oyeuafxhivp90@gmail.com',
#    'and',
#    'meetings',
#    'in',
#    'Jacksonville',
#    'Mandarin',
#    ',',
#    'United',
#    'States',
#    '.'],
#   'ner': [[16, 16, 'EMAIL'], [20, 21, 'CITY']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Formulario',
#    'E&O</p><p',
#    '>',
#    'Posición',
#    ':',
#    'Reparador',
#    'de',
#    'bicicletas</p><p',
#    '>',
#    'Correo',
#    ':',
#    'nistret.gardi1984@outlook.com</p><p',
#    '>',
#    'Tarjeta',
#    'de',
#    'crédito',
#    ':',
#    '61391203009631106068</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['2',
#    'Pediatric',
#    'Emergency',
#    'Care',
#    'Report',
#    'Report',
#    'detailing',
#    'emergency',
#    'medical',
#    'care',
#    'provided',
#    'to',
#    'pediatric',
#    'patients',
#    '.',
#    'Incident',
#    'relating',
#    'to',
#    'Faaisa',
#    "'s",
#    'severe',
#    'infection',
#    ',',
#    'action',
#    'required',
#    'from',
#    'Lee',
#    ',',
#    'Hughes',
#    'and',
#    'Sutton',
#    ',',
#    'where',
#    'the',
#    'patient',
#    'is',
#    'registered',
#    '.',
#    'Communication',
#    'setup',
#    'through',
#    'faaisötsch@gmail.com',
#    '.'],
#   'ner': [[18, 18, 'GIVENNAME'], [41, 41, 'EMAIL']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Nome',
#    'paziente',
#    ':',
#    'GVR784413P',
#    ',',
#    'Età',
#    ':',
#    '49',
#    ',',
#    'Occhi',
#    ':',
#    'Nocciola</p><p',
#    '>',
#    'Medicazione',
#    'somministrata',
#    ':',
#    'Lorazepam',
#    '.',
#    'Somministrato',
#    'da',
#    ':',
#    'GVR784413P.',
#    'Osservazioni',
#    ':',
#    'lieve',
#    'aumento',
#    "dell'",
#    'energia',
#    '.',
#    'Prossima',
#    'somministrazione',
#    ':',
#    '28/10/1993.</p',
#    '>'],
#   'ner': [[6, 6, 'IDCARDNUM']]},
#  {'tokenized_text': ['Stiamo',
#    'conducendo',
#    'uno',
#    'studio',
#    'sui',
#    'risultati',
#    'basati',
#    'su',
#    'diverse',
#    'regioni',
#    'geografiche',
#    '.',
#    'Controlla',
#    'la',
#    'mappa',
#    'a',
#    '[',
#    '47.31619',
#    ',',
#    '8.43',
#    ']',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Hey',
#    'Sharda',
#    ',',
#    'verifica',
#    "l'",
#    'indirizzo',
#    '(',
#    '61045',
#    ')',
#    'per',
#    'la',
#    'polizza',
#    'di',
#    'assicurazione',
#    '.',
#    'Grazie',
#    '!'],
#   'ner': [[1, 1, 'SURNAME'], [7, 7, 'ZIPCODE']]},
#  {'tokenized_text': ['La',
#    'evaluación',
#    'en',
#    'España',
#    ',',
#    'MC',
#    'indicó',
#    'un',
#    'valor',
#    'alto',
#    'para',
#    'la',
#    'pieza',
#    '.',
#    'Detalles',
#    'del',
#    'propietario',
#    ',',
#    'contacto',
#    ':',
#    '+0953356',
#    '9401',
#    '.'],
#   'ner': [[20, 21, 'TELEPHONENUM']]},
#  {'tokenized_text': ['Submit',
#    'necessary',
#    'identification',
#    'details',
#    ',',
#    'including',
#    'the',
#    'borrower',
#    '’s',
#    'ID',
#    'card',
#    'number',
#    '404426284245',
#    ',',
#    'for',
#    'legal',
#    'documentation',
#    'and',
#    'verification',
#    '.'],
#   'ner': [[12, 12, 'IDCARDNUM']]},
#  {'tokenized_text': ['IP',
#    'ownership',
#    'legally',
#    'reserved',
#    '.',
#    'ID',
#    'compresses',
#    'Nederland',
#    'protocol',
#    'regulations',
#    '.',
#    'Queries',
#    ':',
#    'https://www.tech.com/'],
#   'ner': []},
#  {'tokenized_text': ['Nombre',
#    ':',
#    'Annagret',
#    ',',
#    'Ciudad',
#    ':',
#    'Roquetas',
#    'de',
#    'Mar',
#    ',',
#    'Ocupación',
#    ':',
#    'Director',
#    'de',
#    'ventas',
#    'y',
#    'comercialización',
#    ',',
#    'Email',
#    ':',
#    '21W@hotmail.com',
#    ',',
#    'Área',
#    ':',
#    'Ingeniería',
#    ',',
#    'Código',
#    'de',
#    'Verificación',
#    ':',
#    '244-08'],
#   'ner': [[2, 2, 'GIVENNAME'], [6, 8, 'CITY'], [20, 20, 'EMAIL']]},
#  {'tokenized_text': ['Eccellente',
#    'articolo',
#    '.',
#    'Vorrei',
#    'condividere',
#    'i',
#    'miei',
#    'pensieri',
#    '.',
#    'Abito',
#    'a',
#    'Torre',
#    '115',
#    ',',
#    'se',
#    'qualcuno',
#    'volesse',
#    'discutere',
#    'di',
#    'persona',
#    '.',
#    'Saluti',
#    '!'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Pollution',
#    'Incident',
#    'No',
#    '.',
#    ':',
#    'DOC-201301',
#    '-',
#    '9718</p><p',
#    '>',
#    'Incident',
#    'Date',
#    ':',
#    '2033',
#    '-',
#    '06',
#    '-',
#    '26T00:00:00</p><p',
#    '>',
#    'Vessel',
#    'Involved',
#    ':',
#    'Certificate',
#    'of',
#    'Deposit',
#    'Account</p><p',
#    '>',
#    'Type',
#    'of',
#    'Pollutant',
#    ':',
#    'Monmouthshire',
#    'Building',
#    'Society</p><p',
#    '>',
#    'Height',
#    'of',
#    'Spill',
#    ':',
#    '150',
#    'cm</p><p',
#    '>',
#    'City',
#    ':',
#    'Swindon</p><p',
#    '>',
#    'Contact',
#    ':',
#    '01.1927',
#    '4830</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['Hi',
#    '1972P17',
#    ',',
#    'do',
#    'you',
#    'think',
#    'the',
#    'employee',
#    'recognition',
#    'programme',
#    'here',
#    'can',
#    'be',
#    'adapted',
#    'for',
#    'Fletcher',
#    'Group',
#    '?'],
#   'ner': [[1, 1, 'USERNAME']]},
#  {'tokenized_text': ['Treatment',
#    'Plan',
#    ':',
#    'Utilise',
#    'client',
#    '-',
#    'preferred',
#    'instruments',
#    'to',
#    'evoke',
#    'positive',
#    'emotional',
#    'responses',
#    '.',
#    'Ensure',
#    'confidentiality',
#    'through',
#    'secure',
#    'Mozilla/5.0',
#    '(',
#    'compatible',
#    ';',
#    'MSIE',
#    '9.0',
#    ';',
#    'Windows',
#    'NT',
#    '11.0',
#    ';',
#    'Trident/3.1',
#    ')',
#    'interfaces',
#    '.',
#    'Billing',
#    'Le0Xak2BBoV8wtlzW8MHh2T9aT6cIKkqVu',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Ciao',
#    'Mae',
#    ',',
#    'il',
#    'tuo',
#    'indirizzo',
#    'secondario',
#    'Casa',
#    'mobile',
#    '196',
#    'è',
#    'ancora',
#    'corretto',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'p>{1',
#    '   ',
#    'Rapport',
#    "d'",
#    'évaluation',
#    'psychologique',
#    '   ',
#    'Évaluation',
#    'détaillée',
#    'de',
#    "l'",
#    'état',
#    'de',
#    'santé',
#    'mentale',
#    'du',
#    'patient',
#    '.',
#    '}',
#    'La',
#    'prise',
#    'en',
#    'compte',
#    'des',
#    'URL',
#    'https://www.monnet.com/',
#    'et',
#    'des',
#    'politiques',
#    "d'",
#    'entreprise',
#    'SN',
#    '-',
#    'K7-X2',
#    '-',
#    '83',
#    'est',
#    'cruciale',
#    'pour',
#    'appréhender',
#    "l'",
#    'état',
#    'du',
#    'patient',
#    '.',
#    'Également',
#    ',',
#    'un',
#    'suivi',
#    'constant',
#    'des',
#    'adresses',
#    '0x8b0e965567363178ba947f2e485f04af79db2cdc',
#    'est',
#    'conseillé.</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'p>2',
#    '  ',
#    'Audit',
#    'Report',
#    '  ',
#    'Detailed',
#    'report',
#    'documenting',
#    'the',
#    'findings',
#    'of',
#    'audits',
#    'conducted',
#    'to',
#    'assess',
#    'compliance',
#    'with',
#    'healthcare',
#    'regulations',
#    '.',
#    'The',
#    'review',
#    'found',
#    'irregularities',
#    'linked',
#    'to',
#    '04558',
#    '.',
#    'Immediate',
#    'actions',
#    'are',
#    'advised',
#    '.',
#    'Any',
#    'concerns',
#    'should',
#    'be',
#    'addressed',
#    'to',
#    '45laurentiu@yahoo.com.</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['Ik',
#    'probeer',
#    'mijn',
#    'wiskundige',
#    'vaardigheden',
#    'bij',
#    'te',
#    'schaven',
#    '.',
#    'Weet',
#    'iemand',
#    'een',
#    'goede',
#    'tutor',
#    'die',
#    'beschikbaar',
#    'is',
#    'in',
#    'de',
#    'ochtend',
#    '?',
#    '7',
#    'tot',
#    '7',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Hola',
#    '96814908722260893676',
#    ',',
#    'actualización',
#    'importante',
#    'sobre',
#    'su',
#    'mediación',
#    'a',
#    'las',
#    '5:45',
#    '.',
#    'No',
#    'olvide',
#    'su',
#    '[',
#    'IPV4_1',
#    ']',
#    'y',
#    'tener',
#    'acceso',
#    'a',
#    'su',
#    '0x040e01c3c07d39f943a1daa457bf3c691b0c2cde',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Thérapie',
#    'comportementale',
#    'pour',
#    '<',
#    'USERNAME_14>.',
#    'Suivi',
#    'des',
#    'progrès',
#    'et',
#    'notes',
#    'envoyés',
#    'à',
#    '<',
#    'EMAIL_30>.',
#    'Paiements',
#    'confirmés',
#    'avec',
#    'la',
#    'carte',
#    '<',
#    'CREDITCARDNUMBER_21',
#    '>',
#    'et',
#    'sécurité',
#    'par',
#    '<',
#    'MACADDRESS_13>.</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['Pollution',
#    'Alert',
#    ':',
#    'Location',
#    'near',
#    '41179',
#    '-',
#    '6391',
#    ',',
#    'reported',
#    'by',
#    'Mister',
#    'Naa',
#    '.',
#    'INCIDENT',
#    'NO',
#    'INV-201103',
#    '-',
#    '1613',
#    '.',
#    'Crew',
#    'involved',
#    'Age',
#    ':',
#    '37',
#    ',',
#    'Gender',
#    ':',
#    'Female',
#    ',',
#    'DL',
#    ':',
#    'VUH07A4F5KQMI',
#    '.',
#    'Financials',
#    ':',
#    '0x04bf69b88da449fb61c44ddf0c5cf6626a5d7f73',
#    '&',
#    'ADQSUSDA3SU',
#    '.',
#    'Cleanup',
#    'PIN',
#    ':',
#    '602.02',
#    '.',
#    'Cost',
#    ':',
#    'United',
#    'States',
#    'Dollar0.0',
#    'm.'],
#   'ner': [[5, 7, 'ZIPCODE'],
#    [12, 12, 'SURNAME'],
#    [32, 32, 'DRIVERLICENSENUM']]},
#  {'tokenized_text': ['Human',
#    'Resources',
#    'team',
#    ',',
#    'please',
#    'review',
#    'the',
#    'compliance',
#    'audit',
#    'for',
#    'Taylor',
#    '-',
#    'Middleton',
#    'by',
#    '2:08',
#    'AM',
#    '.',
#    'The',
#    'details',
#    'are',
#    'available',
#    'at',
#    'https://wood-carroll.com/.'],
#   'ner': []},
#  {'tokenized_text': ['Abbiamo',
#    'bisogno',
#    'della',
#    'data',
#    'di',
#    'nascita',
#    'settembre',
#    '12º',
#    ',',
#    '1957',
#    'e',
#    'del',
#    'numero',
#    'social',
#    '756',
#    '-',
#    '6810',
#    '-',
#    '7973',
#    '-',
#    '70',
#    'per',
#    'completare',
#    'i',
#    'documenti',
#    '.'],
#   'ner': [[6, 9, 'DATEOFBIRTH'], [14, 20, 'SOCIALNUM']]},
#  {'tokenized_text': ['Ciao',
#    'Piano',
#    'di',
#    'Accumulo',
#    '90',
#    ',',
#    'hai',
#    'visto',
#    "l'",
#    'ultima',
#    'normativa',
#    'sui',
#    'droni',
#    '?',
#    'Mi',
#    'puoi',
#    'dare',
#    'il',
#    'tuo',
#    'numero',
#    'VRM',
#    'EN-0974',
#    'e',
#    'doc',
#    '.',
#    'identificativo',
#    'ORD-201409',
#    '-',
#    '1839',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['Bonjour',
#    ',',
#    'pourriez',
#    '-vous',
#    'confirmer',
#    'si',
#    'cette',
#    'URL',
#    'est',
#    'correcte',
#    ':',
#    'http://www.quartier.com/',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['Doctor',
#    'Capitán',
#    ',',
#    'ya',
#    'revisé',
#    'el',
#    'caso',
#    'de',
#    'Pichardo',
#    '.',
#    'Podría',
#    'tener',
#    'un',
#    'trastorno',
#    'del',
#    'estado',
#    'de',
#    'ánimo',
#    '.',
#    'Quisiera',
#    'discutir',
#    'su',
#    'tratamiento',
#    'a',
#    'las',
#    '5:35',
#    '.',
#    'Un',
#    'saludo',
#    '.'],
#   'ner': [[8, 8, 'SURNAME']]},
#  {'tokenized_text': ['Hi',
#    'Field',
#    'seismologist',
#    ',',
#    'can',
#    'you',
#    'validate',
#    'the',
#    'L7cS1gSHfMrUR1UClUaK3NmUOq2lt5ZP4Y',
#    'used',
#    'in',
#    'the',
#    'recent',
#    'funding',
#    'enactments',
#    'under',
#    'ENG',
#    '?',
#    'Check',
#    'the',
#    'database',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Inserisci',
#    'il',
#    'numero',
#    'identificativo',
#    'D5956266',
#    'e',
#    'il',
#    'numero',
#    'di',
#    'polizza',
#    'CH-IT-7970-A332',
#    'per',
#    'il',
#    'consenso',
#    'presso',
#    'Duncan',
#    ',',
#    'Charles',
#    'and',
#    'Garcia',
#    '.'],
#   'ner': [[4, 4, 'IDCARDNUM']]},
#  {'tokenized_text': ['Goedemiddag',
#    'Studentenrekening',
#    ',',
#    'ik',
#    'heb',
#    'de',
#    'balans',
#    'geüpdatet',
#    'naar',
#    '793183',
#    '.',
#    'Controleer',
#    'het',
#    'snelst',
#    'mogelijk',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Care',
#    'protocol',
#    ':',
#    '\n',
#    '-',
#    'Antipsychotic',
#    'meds',
#    'in',
#    'the',
#    'morning',
#    '.',
#    '\n',
#    '-',
#    'Weekly',
#    'therapy',
#    'support',
#    '.',
#    '\n',
#    '-',
#    'Monthly',
#    'evaluation',
#    '.',
#    '\n',
#    '-',
#    'Patient',
#    'Height',
#    ':',
#    '186',
#    'cm',
#    '/',
#    '6',
#    "'",
#    '1',
#    '"',
#    '\n',
#    '-',
#    'Identification',
#    ':',
#    'ORDER-202005',
#    '-',
#    '6794',
#    '\n',
#    '-',
#    'Residence',
#    ':',
#    '96',
#    'Pistol',
#    'Range',
#    'Road',
#    ',',
#    'Warren',
#    ',',
#    '46135',
#    '\n',
#    '-',
#    'Safety',
#    'PIN',
#    ':',
#    '0592'],
#   'ner': [[45, 45, 'BUILDINGNUM'],
#    [46, 48, 'STREET'],
#    [50, 50, 'CITY'],
#    [52, 52, 'ZIPCODE']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Type',
#    'évaluation',
#    ':',
#    'Comportement',
#    '.',
#    'Nom',
#    ':',
#    'Nicole',
#    ',',
#    'âge',
#    '76',
#    ',',
#    'fait',
#    'par',
#    'éditeur',
#    'à',
#    'Launay',
#    'en',
#    'FR.</p',
#    '>'],
#   'ner': [[10, 10, 'GIVENNAME']]},
#  {'tokenized_text': ['Kan',
#    'je',
#    'de',
#    'lesplannen',
#    'voor',
#    'Personeelszaken',
#    'updaten',
#    '?',
#    'We',
#    'hebben',
#    'een',
#    'salarisverhoging',
#    'nodig',
#    'voor',
#    'de',
#    'Deeltijds',
#    'team',
#    ',',
#    'zoals',
#    'besproken',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Ho',
#    'bisogno',
#    'della',
#    'tua',
#    'licenza',
#    '9905129871',
#    'e',
#    'del',
#    'numero',
#    'di',
#    'sicurezza',
#    'sociale',
#    'Abd',
#    '.',
#    'Erd.15.I.85.5.AEM',
#    'per',
#    'proseguire',
#    '.'],
#   'ner': [[5, 5, 'DRIVERLICENSENUM'], [12, 14, 'SOCIALNUM']]},
#  {'tokenized_text': ['Session',
#    '44',
#    ':',
#    'Self',
#    '-',
#    'Reflection',
#    '\n',
#    'Date',
#    ':',
#    'February/41',
#    '\n',
#    'Exercises',
#    'in',
#    'self',
#    '-',
#    'reflection',
#    '.',
#    '\n',
#    'Location',
#    ':',
#    'Cheyenne',
#    '\n',
#    'Balance',
#    ':',
#    '22.2861b',
#    '\n',
#    'Social',
#    'Number',
#    ':',
#    '676712970'],
#   'ner': [[20, 20, 'CITY'], [29, 29, 'SOCIALNUM']]},
#  {'tokenized_text': ['Facturation',
#    'prévue',
#    'sur',
#    'votre',
#    'carte',
#    'CUP',
#    'le',
#    '25/12/1996',
#    ',',
#    'montant',
#    ':',
#    '$',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['We',
#    'hebben',
#    'nog',
#    'polisnummers',
#    'voor',
#    'Z.',
#    'straat',
#    'per',
#    '05/02/1976',
#    'nodig',
#    '.',
#    'Update',
#    'de',
#    'gegevens',
#    'aub',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Quel',
#    'est',
#    'le',
#    'meilleur',
#    'moyen',
#    'de',
#    'tenir',
#    'à',
#    'jour',
#    'les',
#    'dossiers',
#    'avec',
#    'des',
#    'numéros',
#    'de',
#    'masque',
#    'comme',
#    '322223489904104632779',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['Nom',
#    'complet',
#    ':',
#    'Nishad',
#    '\n',
#    'Numéro',
#    'de',
#    'sécurité',
#    'sociale',
#    ':',
#    '2.42.03.21938.755.68',
#    '\n',
#    'Numéro',
#    'de',
#    'politique',
#    ':',
#    'NIHA19918820',
#    '\n',
#    'Numéro',
#    'de',
#    'bâtiment',
#    ':',
#    '2505'],
#   'ner': [[3, 3, 'GIVENNAME'],
#    [10, 10, 'SOCIALNUM'],
#    [22, 22, 'BUILDINGNUM']]},
#  {'tokenized_text': ['Ciao',
#    ',',
#    'il',
#    'paziente',
#    'con',
#    'VIN',
#    'A825G0BU9V82RJRA0',
#    'ha',
#    'una',
#    'nuova',
#    'prescrizione',
#    '.',
#    'Tutti',
#    'i',
#    'dettagli',
#    'sono',
#    'su',
#    'http://torlonia.com/.'],
#   'ner': []},
#  {'tokenized_text': ["L'",
#    'ultimo',
#    'gruppo',
#    'di',
#    'controllo',
#    'aveva',
#    'tutti',
#    'veicoli',
#    'con',
#    'VIN',
#    'DVPA4P8X155LZDPPU',
#    '.',
#    'Strana',
#    'correlazione',
#    'con',
#    'il',
#    'test',
#    'di',
#    'sensibilità',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Looking',
#    'forward',
#    'to',
#    'our',
#    'humanistic',
#    'psychology',
#    'chat',
#    '.',
#    'Business',
#    'Account',
#    "'s",
#    'analysis',
#    'on',
#    'intrinsic',
#    'motivation',
#    'will',
#    'be',
#    'useful',
#    'for',
#    'our',
#    'meeting',
#    '.',
#    'Meet',
#    'at',
#    '17',
#    'on',
#    'Eckersley',
#    'Fold',
#    'Lane',
#    '.'],
#   'ner': [[26, 28, 'STREET']]},
#  {'tokenized_text': ['Salut',
#    'Ranko',
#    ',',
#    'impressionnant',
#    'cette',
#    'nouvelle',
#    'thérapie',
#    'VR',
#    ',',
#    'tu',
#    'devrais',
#    'vraiment',
#    'la',
#    'tester',
#    '.',
#    'On',
#    'parle',
#    'de',
#    'résultats',
#    'incroyables',
#    '!'],
#   'ner': [[1, 1, 'GIVENNAME']]},
#  {'tokenized_text': ['Quiero',
#    'compartir',
#    'mi',
#    'Litecoin',
#    '(',
#    'Lg22OlP5IbmyZlH7z8rRkJwbQEdWcM4Onj',
#    ')',
#    'para',
#    'colaboraciones',
#    'en',
#    'temas',
#    'legales',
#    'de',
#    'protección',
#    'animal',
#    '.',
#    'Mi',
#    'área',
#    'de',
#    'trabajo',
#    'es',
#    'Soporte',
#    'Técnico',
#    'y',
#    'resido',
#    'en',
#    'Lucena',
#    '.',
#    '¡',
#    'Gracias',
#    'a',
#    'todos',
#    '!'],
#   'ner': [[26, 26, 'CITY']]},
#  {'tokenized_text': ['<',
#    'form',
#    '>',
#    '<',
#    'label',
#    '>',
#    'Nome:</label',
#    '>',
#    '<',
#    'input',
#    "type='text",
#    "'",
#    "name='nome",
#    "'",
#    '/',
#    '>',
#    '<',
#    'label',
#    '>',
#    'Cognome:</label',
#    '>',
#    '<',
#    'input',
#    "type='text",
#    "'",
#    "name='cognome",
#    "'",
#    '/',
#    '>',
#    '<',
#    'label',
#    '>',
#    'Indirizzo:</label',
#    '>',
#    '<',
#    'input',
#    "type='text",
#    "'",
#    "name='street",
#    "'",
#    "value='Via",
#    'della',
#    'Valle',
#    "'",
#    '/',
#    '>',
#    '<',
#    'label',
#    '>',
#    'Tax',
#    'Number:</label',
#    '>',
#    '<',
#    'input',
#    "type='text",
#    "'",
#    "name='taxnum",
#    "'",
#    "value='IT92034864123",
#    "'",
#    '/></form',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['Salut',
#    'Jouko',
#    ',',
#    'notre',
#    'vétérinaire',
#    'a',
#    'dit',
#    'de',
#    'consulter',
#    'les',
#    'informations',
#    'sur',
#    'http://www.bourquin.org/',
#    'à',
#    'propos',
#    'de',
#    'notre',
#    'chat',
#    'malade',
#    '.',
#    'Alerte',
#    'lancée',
#    'à',
#    '10',
#    ':',
#    'ba:67',
#    ':',
#    'cf',
#    ':',
#    'fc:6b',
#    '.'],
#   'ner': [[1, 1, 'GIVENNAME']]},
#  {'tokenized_text': ['Pfalzer',
#    ',',
#    'nous',
#    'devons',
#    'vérifier',
#    'ton',
#    'passeport',
#    '(',
#    'P3303810',
#    ')',
#    'pour',
#    'finaliser',
#    'le',
#    'contrat',
#    '.'],
#   'ner': [[0, 0, 'SURNAME']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Behandelplan:</p><p',
#    '>',
#    'Focus',
#    'client',
#    ':',
#    'Pellegrin.</p><p',
#    '>',
#    'Therapeutische',
#    'sessies',
#    'in',
#    'Erp.</p><p',
#    '>',
#    'Locatiegegevens',
#    ':',
#    'Gebouwnummer',
#    '832</p><p',
#    '>',
#    'Details',
#    'in',
#    'document',
#    ':',
#    'FACT-202303-3374</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['Noté',
#    'en',
#    'el',
#    'video',
#    'que',
#    'el',
#    'director',
#    'de',
#    'Voluntario',
#    'tiene',
#    'ojos',
#    'Gris',
#    'y',
#    'mide',
#    '169',
#    'cm',
#    'cm',
#    '.',
#    'Está',
#    'registrado',
#    'en',
#    'Carretera',
#    'de',
#    'València',
#    '.',
#    '¿',
#    'Verificamos',
#    'su',
#    'identificación',
#    'Y7493716',
#    'M',
#    'antes',
#    'del',
#    'seguro',
#    '?'],
#   'ner': [[21, 23, 'STREET'], [29, 30, 'IDCARDNUM']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Evaluación',
#    'del',
#    'riesgo',
#    ':',
#    'A',
#    'fecha',
#    'de',
#    '2088-05-22T00:00:00',
#    'se',
#    'observa',
#    'un',
#    'endeudamiento',
#    'moderado',
#    '.',
#    'Coordenadas',
#    'geográficas',
#    'de',
#    'la',
#    'propiedad',
#    ':',
#    '[',
#    '36.56',
#    ',',
#    '-6.2246',
#    ']',
#    '.',
#    'Correo',
#    ':',
#    'anna-lina.sagrera@protonmail.com',
#    '.',
#    'Número',
#    'fiscal',
#    ':',
#    'Z0793928C.',
#    'Verificación',
#    'de',
#    'MAC',
#    ':',
#    '56:47',
#    ':',
#    'eb',
#    ':',
#    'dc:67',
#    ':',
#    'd0.</p',
#    '>'],
#   'ner': [[31, 31, 'EMAIL']]},
#  {'tokenized_text': ['Salut',
#    ',',
#    'il',
#    'faut',
#    'que',
#    'tu',
#    'transmettes',
#    'ton',
#    'W1301224406232',
#    'par',
#    'mail',
#    'à',
#    'Pasquier',
#    '.'],
#   'ner': [[8, 8, 'IDCARDNUM']]},
#  {'tokenized_text': ['Salut',
#    'Madame',
#    'Marsaut',
#    ',',
#    'peux',
#    '-',
#    'tu',
#    'partager',
#    'les',
#    'coordonnées',
#    'géographiques',
#    '[',
#    '47.1219',
#    ',',
#    '7.726',
#    ']',
#    'du',
#    'bâtiment',
#    '92',
#    'pour',
#    'le',
#    'rapport',
#    '?'],
#   'ner': [[2, 2, 'SURNAME'], [18, 18, 'BUILDINGNUM']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Io',
#    ',',
#    '[',
#    'null',
#    ']',
#    ',',
#    'firmo',
#    'questo',
#    'modulo',
#    'di',
#    'rinuncia',
#    'consapevole',
#    'delle',
#    'implicazioni',
#    '.',
#    'Il',
#    'mio',
#    'numero',
#    'di',
#    'sicurezza',
#    'sociale',
#    'è',
#    '756',
#    '-',
#    '2155',
#    '-',
#    '0593',
#    '-',
#    '32',
#    ',',
#    'il',
#    'mio',
#    'PIN',
#    'è',
#    '5617710',
#    '.',
#    'La',
#    'mia',
#    'data',
#    'di',
#    'nascita',
#    'è',
#    '1984',
#    '-',
#    '08',
#    '-',
#    '19T00:00:00.</p',
#    '>'],
#   'ner': [[25, 31, 'SOCIALNUM']]},
#  {'tokenized_text': ['<',
#    'div',
#    '>',
#    '\n',
#    '<',
#    'p',
#    '>',
#    'Le',
#    'Trust',
#    'Agreement',
#    'signé',
#    'par',
#    'catalin-mihai.jhenny@yahoo.com',
#    'et',
#    'géré',
#    'par',
#    'catalin-mihai.jhenny@yahoo.com',
#    'stipule',
#    "l'",
#    'utilisation',
#    'des',
#    'ressources',
#    'situées',
#    'au',
#    '3',
#    '.',
#    "L'",
#    'adresse',
#    'IP',
#    '[',
#    'IPV4_6',
#    ']',
#    'et',
#    'le',
#    'numéro',
#    'de',
#    'téléphone',
#    '09',
#    '-',
#    '60',
#    '16.87',
#    '93',
#    'doivent',
#    'être',
#    'utilisés',
#    'pour',
#    'toute',
#    'communication',
#    'officielle.</p',
#    '>',
#    '\n',
#    '<',
#    '/div',
#    '>'],
#   'ner': [[12, 12, 'EMAIL'],
#    [16, 16, 'EMAIL'],
#    [24, 24, 'BUILDINGNUM'],
#    [37, 41, 'TELEPHONENUM']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Egregio',
#    'Signore',
#    'Borisav,</p><p',
#    '>',
#    'Richiesta',
#    'di',
#    'trasferimento',
#    ':',
#    'Conto',
#    'bancario',
#    'Bonus',
#    'Cultura',
#    'Giovani',
#    ',',
#    'Organizzazione',
#    ':',
#    'Farnese',
#    ',',
#    'Piane',
#    'e',
#    'Camicione',
#    'SPA',
#    ',',
#    'Codice',
#    'PIN',
#    ':',
#    '61852.</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['Hey',
#    'Shener',
#    ',',
#    'do',
#    'you',
#    'think',
#    'moving',
#    'to',
#    'Brush',
#    'Creek',
#    'is',
#    'a',
#    'good',
#    'idea',
#    'for',
#    'lower',
#    'dental',
#    'costs',
#    '?',
#    'Have',
#    'my',
#    '0.02',
#    'm',
#    'budget',
#    'for',
#    'that',
#    ',',
#    'and',
#    'my',
#    'credit',
#    'rating',
#    'is',
#    'still',
#    'okay',
#    '.',
#    'Any',
#    'tips',
#    'or',
#    'clinics',
#    '?'],
#   'ner': [[1, 1, 'GIVENNAME'], [8, 9, 'CITY']]},
#  {'tokenized_text': ['De',
#    'gezondheidsdata',
#    'van',
#    'NL',
#    'moeten',
#    'nog',
#    'geanalyseerd',
#    'worden',
#    '.',
#    'Kun',
#    'je',
#    'dit',
#    'snel',
#    'nakijken',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['Buongiorno',
#    ',',
#    'il',
#    'tuo',
#    'stipendio',
#    'per',
#    "l'",
#    'incarico',
#    'presso',
#    'Morris-Finley',
#    'sarà',
#    'di',
#    '184.094k',
#    'CHF',
#    '.',
#    'Procediamo',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['School',
#    'drill',
#    'updates',
#    'at',
#    'G@outlook.com',
#    '.',
#    'Validate',
#    'firewall',
#    '[',
#    'IPV4_7',
#    ']',
#    'settings',
#    '.',
#    'Are',
#    '3GRWK4xlz7SKRNnjzclOPyJVDyoHesmt6',
#    'T',
#    'records',
#    'up',
#    '-',
#    'to',
#    '-',
#    'date',
#    '?'],
#   'ner': [[4, 4, 'EMAIL']]},
#  {'tokenized_text': ['Ils',
#    "m'",
#    'ont',
#    'demandé',
#    'ma',
#    'carte',
#    'de',
#    'crédit',
#    'pour',
#    'continuer',
#    'le',
#    'processus',
#    '.',
#    "C'",
#    'est',
#    '3529254268701722',
#    '.',
#    'Devrais',
#    '-je',
#    'leur',
#    'donner',
#    '?'],
#   'ner': [[15, 15, 'CREDITCARDNUMBER']]},
#  {'tokenized_text': ['Bonjour',
#    'Marco',
#    '-',
#    'Antonio',
#    ',',
#    'pour',
#    'ta',
#    'nouvelle',
#    'assurance',
#    '-',
#    'vie',
#    ',',
#    'j’',
#    'ai',
#    'besoin',
#    'de',
#    'confirmer',
#    'ton',
#    'adresse',
#    'Aeschimoos',
#    'et',
#    'ta',
#    'date',
#    'de',
#    'naissance',
#    'juillet',
#    '24e',
#    ',',
#    '1960',
#    '.'],
#   'ner': [[1, 3, 'GIVENNAME'], [19, 19, 'STREET'], [25, 28, 'DATEOFBIRTH']]},
#  {'tokenized_text': ['Fecha',
#    'de',
#    'nacimiento',
#    'del',
#    'titular',
#    ':',
#    'julio/38',
#    ',',
#    'nivel',
#    'crediticio',
#    ':',
#    '659',
#    '.'],
#   'ner': [[6, 6, 'DATEOFBIRTH']]},
#  {'tokenized_text': ['Allô',
#    'Laoresa',
#    ',',
#    'pourrais',
#    '-',
#    'tu',
#    'confirmer',
#    'ton',
#    'identité',
#    'avec',
#    'ton',
#    'numéro',
#    'de',
#    'carte',
#    "d'",
#    'identité',
#    '(',
#    'L0023935',
#    ')',
#    '?',
#    'On',
#    'a',
#    'besoin',
#    'de',
#    'le',
#    'vérifier',
#    'pour',
#    'la',
#    'sécurité',
#    '.'],
#   'ner': [[1, 1, 'GIVENNAME'], [17, 17, 'IDCARDNUM']]},
#  {'tokenized_text': ['Hey',
#    ',',
#    'did',
#    'you',
#    'know',
#    'that',
#    'sleep',
#    'changes',
#    'can',
#    'affect',
#    'your',
#    'mental',
#    'health',
#    '?',
#    'Check',
#    'out',
#    'the',
#    'article',
#    'I',
#    'found',
#    'on',
#    'psychology',
#    'forums',
#    '.',
#    'They',
#    'mentioned',
#    'some',
#    'data',
#    'from',
#    '29/05/2038',
#    'and',
#    'how',
#    'it',
#    'relates',
#    'to',
#    'common',
#    'issues',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Per',
#    'favore',
#    ',',
#    'mi',
#    'invii',
#    'il',
#    'tuo',
#    'numero',
#    'di',
#    'carta',
#    'di',
#    'credito',
#    '3591499577857977',
#    'e',
#    'il',
#    'numero',
#    'di',
#    'passaporto',
#    'W0641724',
#    'per',
#    'il',
#    'pagamento',
#    '.'],
#   'ner': [[12, 12, 'CREDITCARDNUMBER']]},
#  {'tokenized_text': ['Incluso',
#    'nel',
#    'curriculum',
#    ',',
#    'c’',
#    'è',
#    'un',
#    'seminario',
#    'su',
#    'larga',
#    'scala',
#    'che',
#    'richiede',
#    'a',
#    'tutti',
#    'i',
#    'partecipanti',
#    'di',
#    'fornire',
#    'il',
#    'numero',
#    'di',
#    'polizza',
#    '[',
#    'CREDITCARDEXPIRYCREDITCARDCVV_1',
#    ']',
#    'e',
#    'IBAN',
#    '[',
#    'IBAN_1',
#    ']',
#    'per',
#    'il',
#    'pagamento',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Titular',
#    ':',
#    'nneksq531578</p><p',
#    '>',
#    'Dirección',
#    'ETH',
#    ':',
#    '0xe987172d46c29b0dbfca2448d8e68ea8ece5ce68</p><p',
#    '>',
#    'Número',
#    'IBAN',
#    ':',
#    'ES5698757575181070925689</p><p',
#    '>',
#    'Color',
#    'de',
#    'ojos',
#    ':',
#    'Gris</p><p',
#    '>',
#    'IPV6',
#    ':',
#    '[',
#    'IPV6_6]</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['Assicurati',
#    'di',
#    'aggiornare',
#    'la',
#    'carta',
#    'di',
#    'credito',
#    'Visa',
#    'prima',
#    'della',
#    'data',
#    'di',
#    'scadenza',
#    ':',
#    '[',
#    'CREDITCARDEXPIRYCREDITCARDCVV_1',
#    ']',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Assessment',
#    'review',
#    'for',
#    'subject',
#    'entity',
#    'at',
#    'SE',
#    '.',
#    'Cranleigh',
#    ':',
#    'Significant',
#    'financial',
#    'concerns',
#    'due',
#    'to',
#    'records',
#    'masked',
#    'under',
#    '730899599637709737007766',
#    'with',
#    'associated',
#    '0044',
#    '-',
#    '14.246',
#    '-',
#    '1908',
#    'contact',
#    'details',
#    '.',
#    'Immediate',
#    'underwriting',
#    'revisions',
#    'required',
#    '.'],
#   'ner': [[8, 8, 'CITY'], [21, 25, 'TELEPHONENUM']]},
#  {'tokenized_text': ['Hey',
#    'John',
#    ',',
#    'have',
#    'you',
#    'checked',
#    'if',
#    'the',
#    '[',
#    'CREDITCARDEXPIRYCREDITCARDCVV_1',
#    ']',
#    'billing',
#    'has',
#    'been',
#    'processed',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['Call',
#    'with',
#    'Abd',
#    ',',
#    'discussing',
#    'Belvedere',
#    'Tiburon',
#    "'s",
#    'need',
#    'for',
#    'equitable',
#    'resources',
#    'in',
#    'SW',
#    '.',
#    'districts',
#    '.',
#    'Use',
#    'portal',
#    'with',
#    '01139',
#    '777',
#    '-',
#    '223',
#    '-',
#    '9132',
#    '.'],
#   'ner': [[2, 2, 'GIVENNAME'], [5, 6, 'CITY'], [20, 25, 'TELEPHONENUM']]},
#  {'tokenized_text': ['Data',
#    'di',
#    'nascita',
#    ':',
#    '3º',
#    'settembre',
#    '2003',
#    'Nome',
#    ':',
#    'Yemima',
#    'Sesso',
#    ':',
#    'Non',
#    '-',
#    'binario',
#    'CAP',
#    ':',
#    '4100'],
#   'ner': [[4, 6, 'DATEOFBIRTH'], [9, 9, 'GIVENNAME'], [17, 17, 'ZIPCODE']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Stratégies',
#    'pour',
#    'Non-binaire',
#    'élève',
#    'né',
#    'le',
#    '12',
#    'mai',
#    '1945',
#    '.',
#    'Activités',
#    ':',
#    'renforcement',
#    'positif',
#    'et',
#    'sessions',
#    'avec',
#    'un',
#    'consultant',
#    'en',
#    'validation',
#    '.',
#    'Évaluation',
#    'mensuelle',
#    'selon',
#    'les',
#    'résultats',
#    'académiques.</p',
#    '>'],
#   'ner': [[9, 11, 'DATEOFBIRTH']]},
#  {'tokenized_text': ['Après',
#    'vérifications',
#    ',',
#    'les',
#    'transferts',
#    'en',
#    'EUR',
#    'semblent',
#    'provenir',
#    'de',
#    '1513268076484',
#    '.',
#    "Qu'",
#    'en',
#    'penses',
#    '-',
#    'tu',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['We',
#    "'re",
#    'scheduling',
#    'a',
#    'family',
#    'therapy',
#    'session',
#    'with',
#    'Semira',
#    'Blue',
#    '.',
#    'Can',
#    'I',
#    'have',
#    'your',
#    'UO29936AQ',
#    'to',
#    'check',
#    'the',
#    'details',
#    '?'],
#   'ner': [[8, 8, 'GIVENNAME'], [15, 15, 'IDCARDNUM']]},
#  {'tokenized_text': ['Ciao',
#    'Blaze',
#    ',',
#    'ho',
#    'notato',
#    'alcune',
#    'attività',
#    'sospette',
#    "dall'",
#    'indirizzo',
#    'IP',
#    '[',
#    'IPV6_1',
#    ']',
#    '.',
#    'Puoi',
#    'verificare',
#    'e',
#    'informarmi',
#    '?',
#    'Grazie',
#    '!'],
#   'ner': [[1, 1, 'GIVENNAME']]},
#  {'tokenized_text': ['Gebruik',
#    'M',
#    'patiëntengegevens',
#    ',',
#    'inclusief',
#    '803278260',
#    'en',
#    'GH778638X03',
#    ',',
#    'om',
#    'hoogwaardige',
#    'zorgverlening',
#    'te',
#    'analyseren',
#    'en',
#    'actieplannen',
#    'te',
#    'ontwikkelen',
#    '.'],
#   'ner': [[5, 5, 'IDCARDNUM']]},
#  {'tokenized_text': ['Lors',
#    'de',
#    'la',
#    'réunion',
#    'sur',
#    'le',
#    'commerce',
#    'global',
#    ',',
#    'nous',
#    'aurons',
#    'besoin',
#    'des',
#    'rapports',
#    'sur',
#    'les',
#    'balances',
#    '(',
#    '501.075k',
#    ')',
#    'et',
#    'les',
#    'comptes',
#    'IBAN',
#    'FR710DVBRRLTP093007598634',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Buenos',
#    'días',
#    ',',
#    'por',
#    'favor',
#    'verifica',
#    'tu',
#    'dirección',
#    'de',
#    'calle',
#    ':',
#    'Circunvalación',
#    'de',
#    'Burgos',
#    'y',
#    'envíala',
#    'a',
#    'rhaverland@hotmail.com',
#    'tan',
#    'pronto',
#    'sea',
#    'posible',
#    '.'],
#   'ner': [[11, 13, 'STREET'], [17, 17, 'EMAIL']]},
#  {'tokenized_text': ['Bonjour',
#    'Maître',
#    ',',
#    'pour',
#    'la',
#    'préparation',
#    'de',
#    'la',
#    'séance',
#    'ACT',
#    ',',
#    'nous',
#    'aurons',
#    'besoin',
#    'de',
#    'ton',
#    'adresse',
#    'secondaire',
#    'Bungalow',
#    '577',
#    'et',
#    'de',
#    'confirmer',
#    'le',
#    'transfert',
#    'de',
#    '136,737.98',
#    'sur',
#    "l'",
#    'IBAN',
#    'CH',
#    '9592',
#    '1169',
#    '9318',
#    '1903',
#    '5',
#    '.',
#    'Merci',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'html',
#    '>',
#    'In',
#    'de',
#    'huidige',
#    'analyse',
#    'SPRONG',
#    'bedrijven',
#    'in',
#    'Bernheze',
#    'zoals',
#    'name',
#    'niet',
#    'goed',
#    'scoren',
#    'op',
#    'IPV4_2',
#    'training',
#    '.',
#    'De',
#    'USERNAME_3',
#    'van',
#    'de',
#    'telemarkten',
#    ' ',
#    'user',
#    'verminderen',
#    'een',
#    'belangrijke',
#    'vulnerability',
#    '.',
#    'Competitors',
#    'ook',
#    'offers',
#    'specific',
#    'marketing',
#    'in',
#    'EYECOLOR_2.</html',
#    '>'],
#   'ner': [[10, 10, 'CITY']]},
#  {'tokenized_text': ['Hallo',
#    'Marketing',
#    'team',
#    ',',
#    'controleer',
#    'aub',
#    'of',
#    'je',
#    'alle',
#    'belevenissen',
#    'hebt',
#    'gedeeld',
#    'voor',
#    'onderzoek',
#    '.',
#    'Gebruik',
#    'het',
#    'ZIPCODE',
#    '7852',
#    'TH.'],
#   'ner': []},
#  {'tokenized_text': ['¿',
#    'El',
#    'seguro',
#    'de',
#    'mascotas',
#    'en',
#    'Cerdanyola',
#    'del',
#    'Vallès',
#    'Bellaterra',
#    'tiene',
#    'restricciones',
#    'por',
#    'edad',
#    'de',
#    'la',
#    'mascota',
#    '?',
#    'Quiero',
#    'asegurar',
#    'a',
#    'mi',
#    'perro',
#    'mayor',
#    '.'],
#   'ner': [[6, 9, 'CITY']]},
#  {'tokenized_text': ['Registro',
#    'interventi',
#    'per',
#    'migliorare',
#    'il',
#    'benessere',
#    'psicofisico',
#    '.',
#    'Monitoraggio',
#    'e',
#    'archiviazione',
#    'via',
#    'IP',
#    '[',
#    'IPV6_6',
#    ']',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Acconsento',
#    'alla',
#    'valutazione',
#    'psicologica',
#    '.',
#    'Anni',
#    '-',
#    '27',
#    ',',
#    'Numero',
#    'fiscale',
#    '-',
#    'IT32813967981',
#    ',',
#    'Banca',
#    '-',
#    'Banca',
#    'Popolare',
#    'di',
#    'Ancona',
#    ',',
#    'contatti',
#    '-',
#    '+128.976',
#    '-',
#    '777',
#    '-',
#    '1482.</p',
#    '>'],
#   'ner': [[15, 15, 'TAXNUM']]},
#  {'tokenized_text': ['Counseling',
#    'for',
#    'student',
#    'Abiéniste',
#    'commenced',
#    ',',
#    'cited',
#    'stress',
#    'over',
#    'family',
#    'finances',
#    '.',
#    'Recent',
#    'BTC',
#    'withdrawal',
#    'logged',
#    'under',
#    '3wWqgCcvuMMdxtP56IbOErAS0bMpDUil5',
#    'm.',
#    'Throughout',
#    'PA',
#    ',',
#    'exhibit',
#    'signs',
#    'of',
#    'anxiety',
#    'entering',
#    '1795',
#    '.',
#    'Recommended',
#    'session',
#    'follow',
#    '-',
#    'up',
#    'on',
#    '2027',
#    '-',
#    '01',
#    '-',
#    '25T00:00:00',
#    '.'],
#   'ner': [[3, 3, 'SURNAME'], [27, 27, 'BUILDINGNUM']]},
#  {'tokenized_text': ['Strategy',
#    ':',
#    'Integrate',
#    'machine',
#    'learning',
#    'in',
#    'Customer',
#    'Service',
#    '.',
#    'Overseer',
#    ':',
#    'Fatjeta',
#    'Protection',
#    ':',
#    '75%L\\Cs@cY'],
#   'ner': [[11, 11, 'GIVENNAME'], [14, 14, 'PASSWORD']]},
#  {'tokenized_text': ['¡',
#    'Felicitaciones',
#    'por',
#    'tu',
#    'esfuerzo',
#    '!',
#    'Por',
#    'favor',
#    ',',
#    'confirma',
#    'la',
#    'fecha',
#    'de',
#    'vencimiento',
#    'de',
#    'tu',
#    'tarjeta',
#    'de',
#    'crédito',
#    '[',
#    'CREDITCARDEXPIRYCREDITCARDCVV_1',
#    ']',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Hola',
#    'Gligovic',
#    ',',
#    '¿',
#    'puedes',
#    'revisar',
#    'los',
#    'detalles',
#    'del',
#    'ES07',
#    '3130',
#    '5271',
#    '28',
#    '1430335583',
#    'antes',
#    'de',
#    'cerrar',
#    'el',
#    'acuerdo',
#    '?',
#    'Gracias',
#    '.'],
#   'ner': [[1, 1, 'SURNAME']]},
#  {'tokenized_text': ['Mi',
#    'terapeuta',
#    'usa',
#    'hipnoterapia',
#    'para',
#    'el',
#    'TLP',
#    '.',
#    'Tiene',
#    'buenas',
#    'referencias',
#    'en',
#    '46367',
#    '.'],
#   'ner': [[12, 12, 'ZIPCODE']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Estudio',
#    ':',
#    'Salud</p><p',
#    '>',
#    'Nombre',
#    ':',
#    'Stefano</p><p',
#    '>',
#    'CVV',
#    ':',
#    '368</p><p',
#    '>',
#    'Cantidad',
#    'solicitada',
#    ':',
#    '402574.76</p><p',
#    '>',
#    'Saldo',
#    'Actual',
#    ':',
#    '0.94m</p><p',
#    '>',
#    'ID',
#    ':',
#    'N7152929T</p',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['Mi',
#    'puoi',
#    'inviare',
#    'i',
#    'dettagli',
#    'della',
#    'polizza',
#    'a',
#    'questa',
#    'email',
#    ':',
#    'altaïr@yahoo.com',
#    '.',
#    'Il',
#    'numero',
#    'della',
#    'polizza',
#    'è',
#    '28I9TV48',
#    '.'],
#   'ner': [[11, 11, 'EMAIL']]},
#  {'tokenized_text': ['Fomentar',
#    'la',
#    'empatía',
#    'usando',
#    'ejercicios',
#    'de',
#    'reconocimiento',
#    'de',
#    'emociones',
#    'y',
#    'colores',
#    'de',
#    'ojos',
#    ',',
#    'por',
#    'ejemplo',
#    ',',
#    'Avellana',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'html><body',
#    '>',
#    'We',
#    'richten',
#    'ons',
#    'op',
#    'financiële',
#    'producten',
#    'die',
#    'duurzaamheid',
#    'bevorderen',
#    '.',
#    'Uw',
#    'unieke',
#    'IBAN',
#    'NLOTR3',
#    '9326757723',
#    'geeft',
#    'toegang',
#    'tot',
#    'gedetailleerde',
#    'informatie',
#    'over',
#    'deze',
#    'producten.</body></html',
#    '>'],
#   'ner': []},
#  {'tokenized_text': ['¡',
#    'Hola',
#    'Tarcisia',
#    '!',
#    'Necesitamos',
#    'revisar',
#    'tu',
#    'salario',
#    '103909.2',
#    'en',
#    'Euro',
#    'para',
#    'el',
#    'próximo',
#    'estudio',
#    'sobre',
#    'bienestar',
#    'laboral',
#    'en',
#    'Merindad',
#    'de',
#    'Cuesta-Urria',
#    '.'],
#   'ner': [[2, 2, 'GIVENNAME'], [19, 21, 'CITY']]},
#  {'tokenized_text': ['adelmina.raffle17',
#    ',',
#    'je',
#    'geboekte',
#    'sessie',
#    'in',
#    'Wassenaar',
#    'is',
#    'geannuleerd',
#    '.',
#    'Wil',
#    'je',
#    'een',
#    'nieuwe',
#    'afspraak',
#    'maken',
#    'via',
#    'de',
#    'URL',
#    'https://www.van.com/',
#    '?'],
#   'ner': [[0, 0, 'USERNAME'], [6, 6, 'CITY']]},
#  {'tokenized_text': ['Beste',
#    'Essila',
#    ',',
#    'is',
#    'je',
#    'VRM-nummer',
#    '82-SRZ-3',
#    'en',
#    'IP-adres',
#    '[',
#    'IPV4_6',
#    ']',
#    'correct',
#    'ingevoerd',
#    '?'],
#   'ner': [[1, 1, 'GIVENNAME']]},
#  {'tokenized_text': ['Is',
#    'Scott',
#    '-',
#    'Walker',
#    'compliant',
#    'with',
#    'zone',
#    'laws',
#    'in',
#    '49441',
#    '-',
#    '5283',
#    '?',
#    'Waiting',
#    'on',
#    'the',
#    'latest',
#    'authorizations',
#    'from',
#    'them',
#    '.'],
#   'ner': [[9, 11, 'ZIPCODE']]},
#  {'tokenized_text': ['The',
#    'budget',
#    'for',
#    'this',
#    'season',
#    '’s',
#    'recruitment',
#    'is',
#    'around',
#    '653.797k',
#    '.',
#    'Make',
#    'sure',
#    'to',
#    'factor',
#    'in',
#    'salaries',
#    'within',
#    'range',
#    '157,025.83',
#    'to',
#    '157,025.83',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'html',
#    '>',
#    '\n\t',
#    '<',
#    'body',
#    '>',
#    '\n\t\t',
#    '<',
#    'p',
#    '>',
#    'Per',
#    'favore',
#    ',',
#    'convalidare',
#    'il',
#    'tuo',
#    'indirizzo',
#    'email',
#    'savoino@yahoo.com',
#    'e',
#    'completare',
#    'la',
#    'registrazione',
#    'usando',
#    'MAC',
#    '5c:3d',
#    ':',
#    'a7:0a:89:2c.</p',
#    '>',
#    '\n\t',
#    '<',
#    '/body',
#    '>',
#    '\n',
#    '<',
#    '/html',
#    '>'],
#   'ner': [[19, 19, 'EMAIL']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Fecha',
#    ':',
#    '29/09/1993',
#    '.',
#    'Nombre',
#    'del',
#    'empleado',
#    ':',
#    'Lilly-Sophie',
#    '.',
#    'Asegúrese',
#    'de',
#    'no',
#    'compartir',
#    'su',
#    'número',
#    'de',
#    'pasaporte',
#    ':',
#    'WME221203',
#    'o',
#    'su',
#    'dirección',
#    'IPv6',
#    ':',
#    '[',
#    'IPV6_1',
#    ']',
#    '.',
#    'Este',
#    'formulario',
#    'es',
#    'esencial',
#    'para',
#    'mantener',
#    'la',
#    'integridad',
#    'de',
#    'los',
#    'documentos',
#    'internos.</p',
#    '>'],
#   'ner': [[11, 11, 'GIVENNAME']]},
#  {'tokenized_text': ['Buongiorno',
#    'Navaratnarajah',
#    ',',
#    'controlla',
#    'il',
#    'tuo',
#    'IBAN',
#    'ITJ1217830151O537591509183',
#    'e',
#    'inviami',
#    'anche',
#    'il',
#    'tuo',
#    'rating',
#    'creditizio',
#    '735',
#    'per',
#    'procedere',
#    'con',
#    'la',
#    'pratica',
#    'edilizia',
#    '.'],
#   'ner': [[1, 1, 'SURNAME']]},
#  {'tokenized_text': ['¿',
#    'Puedes',
#    'validar',
#    'el',
#    'BIC',
#    'ROKBUS9I',
#    'y',
#    'actualizarlo',
#    'en',
#    'el',
#    'sistema',
#    '?',
#    'Habrá',
#    'una',
#    'auditoría',
#    'pronto',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Les',
#    'pertes',
#    'potentielles',
#    'pour',
#    'Schweiz',
#    'atteignent',
#    '761573',
#    'CHF',
#    '.',
#    'Consulter',
#    'http://cossy.ch/',
#    'pour',
#    'la',
#    'révision',
#    'du',
#    'rapport',
#    'et',
#    'contacter',
#    '1997biand@tutanota.com',
#    '.'],
#   'ner': [[18, 18, 'EMAIL']]},
#  {'tokenized_text': ['Bonjour',
#    '1957bastron',
#    ',',
#    'pour',
#    'une',
#    'sécurité',
#    'maximale',
#    ',',
#    'votre',
#    'numéro',
#    'IMEI',
#    'est',
#    'maintenant',
#    'enregistré',
#    ':',
#    '376816748474827',
#    '.'],
#   'ner': [[1, 1, 'USERNAME']]},
#  {'tokenized_text': ['Dear',
#    'Eltiona',
#    ',',
#    'could',
#    'you',
#    'provide',
#    'your',
#    'Davidsonville',
#    'address',
#    'and',
#    'your',
#    'current',
#    'Sales',
#    'role',
#    'for',
#    'KYC',
#    '?'],
#   'ner': [[1, 1, 'GIVENNAME'], [7, 7, 'CITY']]},
#  {'tokenized_text': ['Estimado',
#    'Dr.',
#    'Avdurahman',
#    ',',
#    'hemos',
#    'recibido',
#    'tu',
#    'correo',
#    'electrónico',
#    'y',
#    'tenemos',
#    'una',
#    'propuesta',
#    'de',
#    'financiación',
#    'del',
#    'banco',
#    'CajaSol',
#    '.',
#    'Acompañar',
#    'con',
#    'el',
#    'número',
#    '130364081708',
#    '.'],
#   'ner': [[2, 2, 'GIVENNAME'], [23, 23, 'SOCIALNUM']]},
#  {'tokenized_text': ['Hi',
#    'Angad',
#    ',',
#    'exploring',
#    'the',
#    'impact',
#    'of',
#    'screen',
#    'time',
#    'on',
#    'kids',
#    "'",
#    'mental',
#    'health',
#    '.',
#    'Thoughts',
#    '?'],
#   'ner': [[1, 1, 'GIVENNAME']]},
#  {'tokenized_text': ['On',
#    'a',
#    'besoin',
#    "d'",
#    'une',
#    'analyse',
#    'comparative',
#    'entre',
#    'les',
#    'comportements',
#    'des',
#    'garde',
#    'à',
#    'cheval',
#    'et',
#    'ceux',
#    'des',
#    'garde',
#    'à',
#    'cheval',
#    '.',
#    'Tu',
#    'as',
#    'des',
#    'données',
#    'de',
#    '21/06/2013',
#    '?'],
#   'ner': []},
#  {'tokenized_text': ['Nous',
#    'avons',
#    'un',
#    'problème',
#    'avec',
#    "l'",
#    'une',
#    'des',
#    'cartes',
#    'de',
#    'crédit',
#    'utilisées',
#    '.',
#    'Les',
#    'détails',
#    'sont',
#    ':',
#    '[',
#    'CREDITCARDEXPIRYCREDITCARDCVV_1].'],
#   'ner': []},
#  {'tokenized_text': ['Salut',
#    'Gorian',
#    ',',
#    'pour',
#    'la',
#    'validation',
#    'des',
#    'rapports',
#    ',',
#    'assure',
#    '-',
#    'toi',
#    'de',
#    'vérifier',
#    "l'",
#    'IP',
#    '[',
#    'IPV4_1].'],
#   'ner': [[1, 1, 'GIVENNAME']]},
#  {'tokenized_text': ['La',
#    'localisation',
#    'des',
#    'données',
#    'est',
#    'au',
#    'N.',
#    'du',
#    'bâtiment',
#    'des',
#    'archives',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Bonjour',
#    'Compte',
#    'Courant',
#    ',',
#    'formation',
#    'soins',
#    'de',
#    'demain',
#    'à',
#    '4:16',
#    '.',
#    'RDV',
#    'dans',
#    'la',
#    'salle',
#    'de',
#    'Misox',
#    '.',
#    'Vérifie',
#    'ta',
#    'boite',
#    'à',
#    'pvpocedbxissc351@hotmail.com',
#    '.'],
#   'ner': [[16, 16, 'CITY'], [22, 22, 'EMAIL']]},
#  {'tokenized_text': ['Affirm',
#    'your',
#    'strengths',
#    '.',
#    'Reflect',
#    'on',
#    'positive',
#    'interactions',
#    'with',
#    'others',
#    ',',
#    'like',
#    'the',
#    'barista',
#    'at',
#    '641',
#    ',',
#    'Buchanan',
#    'Ranch',
#    'Road',
#    '.',
#    'Journal',
#    'your',
#    'thoughts',
#    'in',
#    'Mozilla/5.0',
#    '(',
#    'compatible',
#    ';',
#    'MSIE',
#    '7.0',
#    ';',
#    'Windows',
#    'NT',
#    '5.1',
#    ';',
#    'Trident/5.0',
#    ')',
#    '.'],
#   'ner': [[15, 15, 'BUILDINGNUM'], [17, 19, 'STREET']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'The',
#    'new',
#    'plan',
#    'will',
#    'include',
#    'ingredients',
#    'locally',
#    'sourced',
#    'and',
#    'organic',
#    'whenever',
#    'possible',
#    '.',
#    'Reach',
#    'out',
#    'to',
#    'hnbrladtc286@gmail.com',
#    'with',
#    'feedback',
#    '.',
#    'Payment',
#    'methods',
#    'include',
#    '67628002133497019',
#    'to',
#    'streamline',
#    'the',
#    'payment',
#    'processes',
#    'effectively.</p',
#    '>'],
#   'ner': [[19, 19, 'EMAIL'], [26, 26, 'CREDITCARDNUMBER']]},
#  {'tokenized_text': ['Counseling',
#    'at',
#    'Scott',
#    '-',
#    'George',
#    'costs',
#    '776757.65',
#    'GBP',
#    'per',
#    'session',
#    '.',
#    'Secure',
#    'data',
#    'transfers',
#    'on',
#    '[',
#    'IPV6_9',
#    ']',
#    '.',
#    'Use',
#    '355.413.0183',
#    'for',
#    'verification',
#    '.'],
#   'ner': [[20, 20, 'SOCIALNUM']]},
#  {'tokenized_text': ['Buongiorno',
#    'Driussi',
#    ',',
#    'per',
#    'completare',
#    'il',
#    'KYC',
#    ',',
#    'abbiamo',
#    'bisogno',
#    'del',
#    'tuo',
#    'numero',
#    'di',
#    'carta',
#    ':',
#    '5083275225611762',
#    ',',
#    'data',
#    'di',
#    'scadenza',
#    ':',
#    '[',
#    'CREDITCARDEXPIRYCREDITCARDCVV_1',
#    ']',
#    'e',
#    'il',
#    'codice',
#    'CVV',
#    '.'],
#   'ner': [[1, 1, 'SURNAME'], [16, 16, 'CREDITCARDNUMBER']]},
#  {'tokenized_text': ['Scusa',
#    'il',
#    'disturbo',
#    ',',
#    'Mae',
#    'Farpour',
#    ',',
#    'ma',
#    'potresti',
#    'spiegarmi',
#    'di',
#    'nuovo',
#    "quell'",
#    'esperimento',
#    "sull'",
#    'inquinamento',
#    'e',
#    'lo',
#    'stress',
#    '?',
#    'Potresti',
#    'mandarmi',
#    'la',
#    'documentazione',
#    'via',
#    'email',
#    ':',
#    'FD2018@outlook.com',
#    '?'],
#   'ner': [[5, 5, 'SURNAME'], [27, 27, 'EMAIL']]},
#  {'tokenized_text': ['Consulta',
#    'http://www.consultoria.com/',
#    'para',
#    'prepararte',
#    'mejor',
#    '.',
#    'Complementa',
#    'nuestra',
#    'guía',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['Recertificazione',
#    ':',
#    'Verifica',
#    'trimestrale',
#    'dei',
#    'numeri',
#    'di',
#    'polizza',
#    'IT-IT-6729-V320',
#    'e',
#    'conferma',
#    'delle',
#    'email',
#    'rijon.bigorra21@tutanota.com',
#    '.'],
#   'ner': [[13, 13, 'EMAIL']]},
#  {'tokenized_text': ['Hola',
#    ',',
#    'el',
#    'saldo',
#    'de',
#    'tu',
#    'cuenta',
#    '(',
#    '957610',
#    ')',
#    'es',
#    'insuficiente',
#    'para',
#    'la',
#    'mediación',
#    'programada',
#    'el',
#    'julio',
#    '25º',
#    ',',
#    '1983',
#    '.',
#    'Actualiza',
#    'tu',
#    'información',
#    'bancaria',
#    ':',
#    'ES9986487595983946118011',
#    'y',
#    'BEGTUSJR',
#    '.'],
#   'ner': []},
#  {'tokenized_text': ['<',
#    'p><strong',
#    '>',
#    'Plan',
#    'detalloción',
#    'de',
#    'tiempo:</strong></p><p',
#    '>',
#    'La',
#    'última',
#    'fase',
#    'del',
#    'proyecto',
#    'requiere',
#    'el',
#    'uso',
#    'del',
#    'vehículo',
#    'con',
#    'matrícula',
#    '1269',
#    'GPJ',
#    'en',
#    'Mozárbez',
#    '.',
#    'Verifique',
#    'el',
#    'balance',
#    'financiero',
#    'en',
#    '148,472.76',
#    'y',
#    'continúe',
#    'con',
#    'el',
#    'seguimiento',
#    'según',
#    'el',
#    'Mozilla/5.0',
#    '(',
#    'iPad',
#    ';',
#    'CPU',
#    'iPad',
#    'OS',
#    '17_3',
#    'like',
#    'Mac',
#    'OS',
#    'X',
#    ')',
#    'AppleWebKit/535.2',
#    '(',
#    'KHTML',
#    ',',
#    'like',
#    'Gecko',
#    ')',
#    'FxiOS/17.7w6111.0',
#    'Mobile/59O717',
#    'Safari/535.2.</p',
#    '>'],
#   'ner': [[23, 23, 'CITY']]},
#  {'tokenized_text': ['Confirma',
#    'la',
#    'URL',
#    'http://www.talleres.net/',
#    'para',
#    'las',
#    'nuevas',
#    'directrices',
#    'de',
#    'outsourcing',
#    'en',
#    'el',
#    'número',
#    'de',
#    'edificio',
#    '143',
#    '.'],
#   'ner': [[15, 15, 'BUILDINGNUM']]},
#  {'tokenized_text': ['Date',
#    ':',
#    '2023',
#    '-',
#    '02',
#    '-',
#    '17',
#    '|',
#    'Commanditaire',
#    ':',
#    '66beryl.abdulhakim',
#    '|',
#    'Ville',
#    ':',
#    'Cheminas',
#    '|',
#    'Énergie',
#    ':',
#    'Électrique',
#    '|',
#    'Consommation',
#    ':',
#    '0.133',
#    'm',
#    'kWh',
#    '|',
#    'Coûts',
#    'totaux',
#    ':',
#    '0.4',
#    'm',
#    '|',
#    'Numéro',
#    'de',
#    'carte',
#    ':',
#    'MIR',
#    '|',
#    'VIN',
#    ':',
#    'P6Y6V6SP80E58SZ2Z',
#    '|',
#    'Clé',
#    "d'",
#    'enquête',
#    ':',
#    'FAC-201602',
#    '-',
#    '1036'],
#   'ner': [[10, 10, 'USERNAME'], [14, 14, 'CITY']]},
#  {'tokenized_text': ['Assets',
#    'on',
#    'September/84',
#    'require',
#    'verification',
#    '.',
#    'Use',
#    '35069',
#    'sent',
#    'to',
#    'arnold.zulkifli@hotmail.com',
#    '.',
#    'Contact',
#    'specialist',
#    'Arnold',
#    ',',
#    'Non',
#    '-',
#    'binary',
#    ',',
#    'Horticultural',
#    'consultant',
#    'for',
#    'guidance',
#    '.'],
#   'ner': [[2, 2, 'DATEOFBIRTH'], [10, 10, 'EMAIL'], [14, 14, 'GIVENNAME']]},
#  {'tokenized_text': ['Discussing',
#    'psychological',
#    'testing',
#    'protocols',
#    ',',
#    'they',
#    'need',
#    '52094588023362',
#    'and',
#    '$',
#    '=',
#    'k7@1=*ZT&J',
#    'for',
#    'access',
#    '.',
#    'Call',
#    'when',
#    'you',
#    '’ve',
#    'got',
#    'time',
#    '?'],
#   'ner': [[9, 11, 'PASSWORD']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Estudiante',
#    ':',
#    'anice.tamgue',
#    '<',
#    'br',
#    '>',
#    'Nota',
#    ':',
#    'Sobresaliente',
#    '<',
#    'br',
#    '>',
#    'Tel',
#    ':',
#    '+34946',
#    '074',
#    '6999',
#    '<',
#    'br',
#    '>',
#    'Direccion',
#    ':',
#    'Villa',
#    '743',
#    ',',
#    'Cervillego',
#    'de',
#    'la',
#    'Cruz',
#    '<',
#    'br',
#    '>',
#    'Evaluación',
#    'final',
#    ':',
#    'Aprobado',
#    '<',
#    'br',
#    '>',
#    'Fecha',
#    'de',
#    'nacimiento',
#    ':',
#    '10º',
#    'abril',
#    '1938</p',
#    '>'],
#   'ner': [[5, 5, 'USERNAME'], [17, 19, 'TELEPHONENUM'], [28, 31, 'CITY']]},
#  {'tokenized_text': ['<',
#    'div',
#    '>',
#    'VR',
#    'language',
#    'learning',
#    'sessions',
#    ',',
#    'headed',
#    'by',
#    'hildebrando',
#    ',',
#    'demand',
#    'verification',
#    'of',
#    'Ethereum',
#    'address',
#    '0xdbc1c21293baf354a610de1e6822ed0717173d7a',
#    'and',
#    'maintaining',
#    'an',
#    'active',
#    'balance',
#    'of',
#    '941771.</div',
#    '>'],
#   'ner': [[10, 10, 'USERNAME']]},
#  {'tokenized_text': ['Salut',
#    'lilav17',
#    ',',
#    'as',
#    '-',
#    'tu',
#    'mis',
#    'à',
#    'jour',
#    'la',
#    'balance',
#    '290k',
#    '?',
#    'Nous',
#    'devons',
#    'synchroniser',
#    'cela',
#    'avec',
#    'notre',
#    'système',
#    'de',
#    'gestion',
#    '.'],
#   'ner': [[1, 1, 'USERNAME']]},
#  {'tokenized_text': ['Waar',
#    'kan',
#    'ik',
#    'huren',
#    'als',
#    'tutor',
#    'zonder',
#    'extra',
#    'kosten',
#    'voor',
#    '1935-05-01T00:00:00',
#    '?',
#    'Hoor',
#    'graag',
#    'waar',
#    'jullie',
#    'ervaring',
#    'mee',
#    'hebben',
#    '.'],
#   'ner': [[10, 10, 'DATEOFBIRTH']]},
#  {'tokenized_text': ['<',
#    'p',
#    '>',
#    'Je',
#    'confirme',
#    'que',
#    'mes',
#    'directives',
#    'de',
#    'soins',
#    'palliatifs',
#    'sont',
#    'documentées',
#    'et',
#    'doivent',
#    'être',
#    'respectées',
#    '.',
#    'Utilisez',
#    'pqplftafnmfibb3715@gmail.com',
#    'pour',
#    'toute',
#    'correspondance.</p',
#    '>'],
#   'ner': [[19, 19, 'EMAIL']]},
#  {'tokenized_text': ['Hey',
#    'fxfbuoaavzadzl20712',
#    ',',
#    'any',
#    'updates',
#    'on',
#    'the',
#    'geo',
#    '-',
#    'coordinate',
#    '[',
#    '55.011',
#    ',',
#    '-1.48',
#    ']',
#    '?',
#    'Discuss',
#    'it',
#    'with',
#    'Ceha',
#    'asap',
#    '.'],
#   'ner': [[1, 1, 'USERNAME'], [19, 19, 'SURNAME']]}]

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "true"

import torch
from gliner import GLiNERConfig, GLiNER
from gliner.training import Trainer, TrainingArguments
from gliner.data_processing.collator import DataCollatorWithPadding, DataCollator
from gliner.utils import load_config_as_namespace
from gliner.data_processing import WordsSplitter, GLiNERDataset

# %%
device = torch.device('cuda:0') if torch.cuda.is_available() else torch.device('cpu')

model = GLiNER.from_pretrained("urchade/gliner_small")
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:551: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(

# %%
# use it for better performance, it mimics original implementation but it's less memory efficient
data_collator = DataCollator(model.config, data_processor=model.data_processor, prepare_labels=True)

# %%
# Optional: compile model for faster training
model.to(device)
print("done")
# Out:
# done

# %%
# calculate number of epochs
num_steps = 500
batch_size = 8
data_size = len(train_dataset)
num_batches = data_size // batch_size
num_epochs = max(1, num_steps // num_batches)

training_args = TrainingArguments(
    output_dir="models",
    learning_rate=5e-6,
    weight_decay=0.01,
    others_lr=1e-5,
    others_weight_decay=0.01,
    lr_scheduler_type="linear", #cosine
    warmup_ratio=0.1,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    num_train_epochs=num_epochs,
    evaluation_strategy="steps",
    save_steps = 100,
    save_total_limit=10,
    dataloader_num_workers = 0,
    use_cpu = False,
    report_to="none",
    )

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=test_dataset,
    tokenizer=model.data_processor.transformer_tokenizer,
    data_collator=data_collator,
)

trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1525: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
#     <div>
#
#       <progress value='501' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [500/500 02:40, Epoch 25/25]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='1' max='3' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1/3 : < :]
#     </div>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-8fc1f212d808> in <cell line: 36>()
#      34 )
#      35
# ---> 36 trainer.train()
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1936                 hf_hub_utils.enable_progress_bars()
#    1937         else:
# -> 1938             return inner_training_loop(
#    1939                 args=args,
#    1940                 resume_from_checkpoint=resume_from_checkpoint,
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2354                     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
#    2355
# -> 2356                     self._maybe_log_save_evaluate(tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2357                 else:
#    2358                     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _maybe_log_save_evaluate(self, tr_loss, grad_norm, model, trial, epoch, ignore_keys_for_eval)
#    2802         metrics = None
#    2803         if self.control.should_evaluate:
# -> 2804             metrics = self._evaluate(trial, ignore_keys_for_eval)
#    2805
#    2806         if self.control.should_save:
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler)
#    2759
#    2760     def _evaluate(self, trial, ignore_keys_for_eval, skip_scheduler=False):
# -> 2761         metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    2762         self._report_to_hp_search(trial, self.state.global_step, metrics)
#    2763
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    3664
#    3665         eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 3666         output = eval_loop(
#    3667             eval_dataloader,
#    3668             description="Evaluation",
#
# /usr/local/lib/python3.10/dist-packages/transformers/trainer.py in evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    3845
#    3846         # Main evaluation loop
# -> 3847         for step, inputs in enumerate(dataloader):
#    3848             # Update the observed num examples
#    3849             observed_batch_size = find_batch_size(inputs)
#
# /usr/local/lib/python3.10/dist-packages/accelerate/data_loader.py in __iter__(self)
#     559                     current_batch = send_to_device(current_batch, self.device, non_blocking=self._non_blocking)
#     560                 self._update_state_dict()
# --> 561                 next_batch = next(dataloader_iter)
#     562                 if batch_index >= self.skip_batches:
#     563                     yield current_batch
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     699                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     700                 self._reset()  # type: ignore[call-arg]
# --> 701             data = self._next_data()
#     702             self._num_yielded += 1
#     703             if (
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     755     def _next_data(self):
#     756         index = self._next_index()  # may raise StopIteration
# --> 757         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     758         if self._pin_memory:
#     759             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
# ---> 55         return self.collate_fn(data)
#
# /usr/local/lib/python3.10/dist-packages/gliner/data_processing/collator.py in __call__(self, input_x)
#      29         raw_batch = self.data_processor.collate_raw_batch(input_x, entity_types = self.entity_types)
#      30
# ---> 31         model_input = self.data_processor.collate_fn(raw_batch, prepare_labels=self.prepare_labels)
#      32         model_input.update({"span_idx": raw_batch['span_idx'] if 'span_idx' in raw_batch else None,
#      33                             "span_mask": raw_batch["span_mask"] if 'span_mask' in raw_batch else None,
#
# /usr/local/lib/python3.10/dist-packages/gliner/data_processing/processor.py in collate_fn(self, batch, prepare_labels, *args, **kwargs)
#     201
#     202     def collate_fn(self, batch, prepare_labels=True, *args, **kwargs):
# --> 203         model_input_batch = self.tokenize_and_prepare_labels(batch, prepare_labels, *args, **kwargs)
#     204         return model_input_batch
#     205
#
# /usr/local/lib/python3.10/dist-packages/gliner/data_processing/processor.py in tokenize_and_prepare_labels(self, batch, prepare_labels, *args, **kwargs)
#     333         tokenized_input = self.tokenize_inputs(batch['tokens'], batch['classes_to_id'])
#     334         if prepare_labels:
# --> 335             labels = self.create_labels(batch)
#     336             tokenized_input['labels'] = labels
#     337         return tokenized_input
#
# /usr/local/lib/python3.10/dist-packages/gliner/data_processing/processor.py in create_labels(self, batch)
#     324         # Convert the list of tensors to a single tensor
#     325         if len(labels_batch) > 1:
# --> 326             labels_batch = pad_2d_tensor(labels_batch)
#     327         else:
#     328             labels_batch = labels_batch[0]
#
# /usr/local/lib/python3.10/dist-packages/gliner/data_processing/utils.py in pad_2d_tensor(key_data)
#      23
#      24         # Pad the tensor along both dimensions
# ---> 25         padded_tensor = torch.nn.functional.pad(tensor, (0, col_padding, 0, row_padding),
#      26                                                                  mode='constant', value=0)
#      27         tensors.append(padded_tensor)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in pad(input, pad, mode, value)
#    5094                     "torch._decomp.decompositions"
#    5095                 )._replication_pad(input, pad)
# -> 5096     return torch._C._nn.pad(input, pad, mode, value)
#    5097
#    5098
#
# RuntimeError: The input size 0, plus negative padding 0 and 0 resulted in a negative output size, which is invalid. Check dimension 1 of your input.

# %%
trained_model = GLiNER.from_pretrained("models/checkpoint-100", load_tokenizer=True)

# %%
text = """
Cristiano Ronaldo dos Santos Aveiro (Portuguese pronunciation: [kɾiʃˈtjɐnu ʁɔˈnaldu]; born 5 February 1985) is a Portuguese professional footballer who plays as a forward for and captains both Saudi Pro League club Al Nassr and the Portugal national team. Widely regarded as one of the greatest players of all time, Ronaldo has won five Ballon d'Or awards,[note 3] a record three UEFA Men's Player of the Year Awards, and four European Golden Shoes, the most by a European player. He has won 33 trophies in his career, including seven league titles, five UEFA Champions Leagues, the UEFA European Championship and the UEFA Nations League. Ronaldo holds the records for most appearances (183), goals (140) and assists (42) in the Champions League, goals in the European Championship (14), international goals (128) and international appearances (205). He is one of the few players to have made over 1,200 professional career appearances, the most by an outfield player, and has scored over 850 official senior career goals for club and country, making him the top goalscorer of all time.
"""

# Labels for entity prediction
labels = ["Person", "Award"] # for v2.1 use capital case for better performance

# Perform entity prediction
entities = trained_model.predict_entities(text, labels, threshold=0.5)

# Display predicted entities and their labels
for entity in entities:
    print(entity["text"], "=>", entity["label"])

# %%
import torch

torch.__version__
# Out:
# '2.3.0+cu121'

# %%
import transformers

transformers.__version__
# Out:
# '4.41.2'

# %%
import huggingface_hub

huggingface_hub.__version__
# Out:
# '0.23.4'

# %%
import accelerate

accelerate.__version__
# Out:
# '0.32.1'
